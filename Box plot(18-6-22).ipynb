# %% [markdown]
# # Box plot

# %%
import matplotlib.pyplot as plt
import numpy as np
data=[10,20,30,40,50]
plt.boxplot(data)
plt.show()

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*10,columns=['A','B','C','D','E'])
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*10,columns=['A','B','C','D','E'])
df.plot(kind='box')
# Out:
# <AxesSubplot:>
