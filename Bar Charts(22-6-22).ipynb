# %%
import matplotlib.pyplot as plt
Country=['USA','India','Germany','UK','France']
GDP_Per_Capita=[48000,38000,50000,45000,44000]
plt.bar(Country,GDP_Per_Capita)
plt.title('Country Vs GDP Per Capita')
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.show()

# %%
import matplotlib.pyplot as plt
Country=['USA','India','Germany','UK','France']
GDP_Per_Capita=[48000,38000,50000,45000,44000]
plt.barh(Country,GDP_Per_Capita)
plt.title('Country Vs GDP Per Capita')
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.show()

# %%
import matplotlib.pyplot as plt
Country=['USA','India','Germany','UK','France']
GDP_Per_Capita=[48000,38000,50000,45000,44000]
plt.bar(Country,GDP_Per_Capita,color="hotpink")
plt.title('Country Vs GDP Per Capita')
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.show()

# %%
import matplotlib.pyplot as plt
Country=['USA','India','Germany','UK','France']
GDP_Per_Capita=[48000,38000,50000,45000,44000]
plt.barh(Country,GDP_Per_Capita,color='r')
plt.title('Country Vs GDP Per Capita')
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.show()

# %%
#Bar Height
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,height=0.1)
plt.show()

# %%
#Bar width
import matplotlib.pyplot as plt
Country=['USA','India','Germany','UK','France']
GDP_Per_Capita=[48000,38000,50000,45000,44000]
plt.bar(Country,GDP_Per_Capita,width=0.2)
plt.title('Country Vs GDP Per Capita')
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.show()
