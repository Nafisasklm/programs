# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40,50])
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,1)
plt.plot(x,y)
#plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40,50])
plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,2,1)
plt.plot(x,y)
#plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40,50])
plt.subplot(2,2,2)
plt.pie(y)
#plot 3
x=np.array([1,2,3,4])
y=np.array([10,12,14,16])
plt.subplot(2,2,3)
plt.bar(x,y)
#plot 4
x=np.array([4,5,6,7,8])
y=np.array([18,20,22,24,26])
plt.subplot(2,2,4)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,4,1)
plt.plot(x,y)
#plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40,50])
plt.subplot(1,4,2)
plt.pie(y)
#plot 3
x=np.array([1,2,3,4])
y=np.array([10,12,14,16])
plt.subplot(1,4,3)
plt.bar(x,y)
#plot 4
x=np.array([4,5,6,7,8])
y=np.array([18,20,22,24,26])
plt.subplot(1,4,4)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,2,1)
plt.plot(x,y)
#plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40,50])
plt.subplot(3,2,2)
plt.pie(y)
#plot 3
x=np.array([1,2,3,4])
y=np.array([10,12,14,16])
plt.subplot(3,2,3)
plt.bar(x,y)
#plot 4
x=np.array([4,5,6,7,8])
y=np.array([18,20,22,24,26])
plt.subplot(3,2,4)
plt.plot(x,y)
plt.show()
#plot 5
x=np.array([1,2,3,4,5])
y=np.array([20,30,40,50,60])
plt.subplot(3,2,5)
plt.plot(x,y)
#plot 6
x=np.array([1,2,3,4,5])
y=np.array([30,40,50,60,70])
plt.subplot(3,2,6)
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Line plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([2,2,6,6,2,4,6,6,4,2])
ypoints=np.array([2,4,4,2,2,3,4,2,3,4])
plt.plot(xpoints,ypoints,marker='*',mec='g',color="hotpink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Line plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([2,2,3,4,4,2,2,4])
ypoints=np.array([2,3,4,3,2,2,3,3])
plt.plot(xpoints,ypoints,marker='o',mec='r',color='pink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Line plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([2,2,3,2.25,3.75,3.50,2.50,2.75,3.25,3,4,4,3.75,3.75,3.25,3.25,2.75,2.75,2.25,2.25,4,2,2,4])
ypoints=np.array([2,3,4,3.25,3.25,3.50,3.50,3.75,3.75,4,3,2,2,3,3,2,2,3,3,2,2,2,3,3])
plt.plot(xpoints,ypoints,marker='o',mec='b',color='Hotpink')
plt.show()

# %% [markdown]
# ##
